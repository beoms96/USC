# %%
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %%R
# df<-read.csv('data/heart-decease-cleveland.csv')
# df

# %%
# %%R
# stem(df$chol)

# %%
import pandas as pd
df = pd.read_csv('data/heart-decease-cleveland.csv')

# %%
import stemgraphic as sg 
sg.stem_graphic(df.chol, compact=True)
# Out:
# (<Figure size 540x576 with 1 Axes>,
#  <matplotlib.axes._axes.Axes at 0x2c2f5fc6588>)
