# %% [markdown]
# Import altair

# %%
import altair as alt

# %% [markdown]
# Let's use iris from vega_datasets

# %%
from vega_datasets import data
df = data.iris()
df.head()
# Out:
#    petalLength  petalWidth  sepalLength  sepalWidth species
# 0          1.4         0.2          5.1         3.5  setosa
# 1          1.4         0.2          4.9         3.0  setosa
# 2          1.3         0.2          4.7         3.2  setosa
# 3          1.5         0.2          4.6         3.1  setosa
# 4          1.4         0.2          5.0         3.6  setosa

# %% [markdown]
# Let's do a scatterplot specifiying the 3 required elements of the grammar (data, aesthetic mappings and mark type)

# %%
alt.Chart(df).mark_point().encode(
    x='petalLength',
    y='petalWidth',
)
# Out:
# Chart({
#   data:      petalLength  petalWidth  sepalLength  sepalWidth    species
#   0            1.4         0.2          5.1         3.5     setosa
#   1            1.4         0.2          4.9         3.0     setosa
#   2            1.3         0.2          4.7         3.2     setosa
#   3            1.5         0.2          4.6         3.1     setosa
#   4            1.4         0.2          5.0         3.6     setosa
#   5            1.7         0.4          5.4         3.9     setosa
#   6            1.4         0.3          4.6         3.4     setosa
#   7            1.5         0.2          5.0         3.4     setosa
#   8            1.4         0.2          4.4         2.9     setosa
#   9            1.5         0.1          4.9         3.1     setosa
#   10           1.5         0.2          5.4         3.7     setosa
#   11           1.6         0.2          4.8         3.4     setosa
#   12           1.4         0.1          4.8         3.0     setosa
# ...

# %%
alt.Chart(df).mark_circle().encode(
  x='petalLength',
  y='petalWidth',
)
# Out:
# Chart({
#   data:      petalLength  petalWidth  sepalLength  sepalWidth    species
#   0            1.4         0.2          5.1         3.5     setosa
#   1            1.4         0.2          4.9         3.0     setosa
#   2            1.3         0.2          4.7         3.2     setosa
#   3            1.5         0.2          4.6         3.1     setosa
#   4            1.4         0.2          5.0         3.6     setosa
#   5            1.7         0.4          5.4         3.9     setosa
#   6            1.4         0.3          4.6         3.4     setosa
#   7            1.5         0.2          5.0         3.4     setosa
#   8            1.4         0.2          4.4         2.9     setosa
#   9            1.5         0.1          4.9         3.1     setosa
#   10           1.5         0.2          5.4         3.7     setosa
#   11           1.6         0.2          4.8         3.4     setosa
#   12           1.4         0.1          4.8         3.0     setosa
# ...

# %% [markdown]
# Customizations

# %%
alt.Chart(df).mark_circle(
).encode(
  x=alt.X('petalLength', axis=alt.Axis(title='petal length (cm)')),
  y=alt.Y('petalWidth', axis=alt.Axis(title='petal width (cm)')),  
  color=alt.Color('species', legend=alt.Legend(title="Species by color")),
  tooltip = ['petalWidth', 'petalLength', 'species']
).interactive()
# Out:
# Chart({
#   data:      petalLength  petalWidth  sepalLength  sepalWidth    species
#   0            1.4         0.2          5.1         3.5     setosa
#   1            1.4         0.2          4.9         3.0     setosa
#   2            1.3         0.2          4.7         3.2     setosa
#   3            1.5         0.2          4.6         3.1     setosa
#   4            1.4         0.2          5.0         3.6     setosa
#   5            1.7         0.4          5.4         3.9     setosa
#   6            1.4         0.3          4.6         3.4     setosa
#   7            1.5         0.2          5.0         3.4     setosa
#   8            1.4         0.2          4.4         2.9     setosa
#   9            1.5         0.1          4.9         3.1     setosa
#   10           1.5         0.2          5.4         3.7     setosa
#   11           1.6         0.2          4.8         3.4     setosa
#   12           1.4         0.1          4.8         3.0     setosa
# ...

# %% [markdown]
# Bar chart of sample type counts

# %%
alt.Chart(df, width=400).mark_bar().encode(
  x=alt.X('species', axis = alt.Axis(labelAngle=0)),
  y='count(species)',
)
# Out:
# Chart({
#   data:      petalLength  petalWidth  sepalLength  sepalWidth    species
#   0            1.4         0.2          5.1         3.5     setosa
#   1            1.4         0.2          4.9         3.0     setosa
#   2            1.3         0.2          4.7         3.2     setosa
#   3            1.5         0.2          4.6         3.1     setosa
#   4            1.4         0.2          5.0         3.6     setosa
#   5            1.7         0.4          5.4         3.9     setosa
#   6            1.4         0.3          4.6         3.4     setosa
#   7            1.5         0.2          5.0         3.4     setosa
#   8            1.4         0.2          4.4         2.9     setosa
#   9            1.5         0.1          4.9         3.1     setosa
#   10           1.5         0.2          5.4         3.7     setosa
#   11           1.6         0.2          4.8         3.4     setosa
#   12           1.4         0.1          4.8         3.0     setosa
# ...

# %% [markdown]
# # 🤔 Exercise 1:
#
# In a new Colab notebook, use `Altair` to create a scatterplot of the `iris` dataset showing `sepal lenght` vs. `sepal width` where the dots are colored by spieces and sized by `petal width`.

# %%
alt.Chart(df).mark_circle().encode(
  x=alt.X('sepalLength', axis=alt.Axis(title='sepal length (cm)')),
  y=alt.Y('sepalWidth', axis=alt.Axis(title='sepal width (cm)')),  
  color=alt.Color('species', legend=alt.Legend(title="Species by color")),
  size='petalWidth'
)

alt.Chart(df).mark_circle().encode(
  x=alt.X('sepalLength', scale=alt.Scale(zero=False)),
  y=alt.Y('petalWidth', axis=alt.Axis(title='petal width (cm)')),  
  color=alt.Color('species', legend=alt.Legend(title="Species by color")),
  size='petalWidth'
)
# Out:
# Chart({
#   data:      petalLength  petalWidth  sepalLength  sepalWidth    species
#   0            1.4         0.2          5.1         3.5     setosa
#   1            1.4         0.2          4.9         3.0     setosa
#   2            1.3         0.2          4.7         3.2     setosa
#   3            1.5         0.2          4.6         3.1     setosa
#   4            1.4         0.2          5.0         3.6     setosa
#   5            1.7         0.4          5.4         3.9     setosa
#   6            1.4         0.3          4.6         3.4     setosa
#   7            1.5         0.2          5.0         3.4     setosa
#   8            1.4         0.2          4.4         2.9     setosa
#   9            1.5         0.1          4.9         3.1     setosa
#   10           1.5         0.2          5.4         3.7     setosa
#   11           1.6         0.2          4.8         3.4     setosa
#   12           1.4         0.1          4.8         3.0     setosa
# ...

# %% [markdown]
# # 🤔Exercise 2:
#
# In a new Colab notebook load `SMO-VOR-2015` and use `plotnine` to create a scatterplot of  the altitudes over time.
#
# You will need to disable the MaxRows check and set the `ptime` to a datetime with:
#
# ```
# alt.data_transformers.disable_max_rows()
# df.ptime = pd.to_datetime(df.ptime)
# ```

# %%
import pandas as pd  #import pandas
df = pd.read_csv('SMO-VOR-2015.csv')
df.head()

df.ptime = pd.to_datetime(df.ptime)
alt.data_transformers.disable_max_rows()

alt.Chart(df).mark_circle().encode(
  x=alt.X('ptime', axis=alt.Axis(title='Penetration time')),
  y=alt.Y('alt', axis=alt.Axis(title='Altitude (feets)')),
  color='ops:O',
  tooltip = ['ptime', 'flight', 'icao', 'ops']
).interactive()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # 🤔Exercise 3:
#
# In a new Colab notebook load `SMO-VOR-2015` and use `Altair` to create an histogram of the altitudes.
#
# You will need to use  `mark_bar` with and set `y='count()'`
#
# To adjust the number of bins use:
#
# Use alt.X()  with `bin=alt.BinParams(maxbins=10)`

# %%
import pandas as pd  #import pandas
df = pd.read_csv('SMO-VOR-2015.csv')
df.head()

df.ptime = pd.to_datetime(df.ptime)
alt.data_transformers.disable_max_rows()

alt.Chart(df).mark_bar().encode(
  x=alt.X('alt', axis=alt.Axis(title='Altitude (feets)'), bin=alt.BinParams(maxbins=10)),
  y='count()'
)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # 🤔Exercise 4:
#
# In a new Colab notebook load `SMO-VOR-2015` and use `Altair` to create an boxplot of the altitudes.
#
# You will need to use  `mark_boxplot`, e.g.,
#
# ```
# mark_boxplot(extent=1.5, ticks=True)
# ```

# %%
import pandas as pd  #import pandas
df = pd.read_csv('SMO-VOR-2015.csv')
df.head()

df.ptime = pd.to_datetime(df.ptime)
df.month = pd.Categorical(df.month, ordered=True,
 categories=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])

alt.data_transformers.disable_max_rows()
df = df.loc[df['ops'] == 'Day']

# Sort should work since 2.4 but it doesn't!

alt.Chart(df, width=400).mark_boxplot(extent=1.5, ticks=True).encode(
    x=alt.X('month:O', 
            sort=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'], 
            title="Months in 2015"),   
    y=alt.Y('alt', scale=alt.Scale(zero=False)), #domain=[2000,10500], clip=True))
    tooltip = ['ptime', 'flight', 'icao', 'ops']
)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
